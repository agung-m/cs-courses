# %%
# !pip install dispy
# Out:
# Collecting dispy
#   Downloading dispy-4.15.2.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 10.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pycos>=4.12.2 (from dispy)
#   Using cached pycos-4.12.2-py3-none-any.whl
# Building wheels for collected packages: dispy
#   Building wheel for dispy (pyproject.toml) ... done
#   Created wheel for dispy: filename=dispy-4.15.2-py3-none-any.whl size=213281 sha256=b62fc78afce3d1fc23698ac65295f9eb995ee5c05838aa903b9af82494d692ee
#   Stored in directory: /root/.cache/pip/wheels/94/34/76/08e61ab60a345d7c7e85416b6a2cf98cd2774fb79c9c256eac
# Successfully built dispy
# Installing collected packages: pycos, dispy
# Successfully installed dispy-4.15.2 pycos-4.12.2

# %%
# Run dispynode in the terminal
# $ dispynode.py -i 0.0.0.0 --name colab1
# Out:
# 2026-03-10 14:27:45 dispynode - version: 4.15.2 (Python 3.12.12), PID: 5401
# 2026-03-10 14:27:45 dispynode - Files will be saved under "/tmp/dispy/node"
# 2026-03-10 14:27:45 pycos - version 4.12.2 (Python 3.12.12) with epoll I/O notifier
# 2026-03-10 14:27:45 dispynode - "9ab6cb613950" serving 2 cpus
# dispynode will quit when current computation from 172.28.0.12 closes.

# %%
import dispy

#nodes = ['192.168.2.*','192.168.1.*']
nodes = ['0.0.0.0','192.168.1.*']

def add_number(num):
    result = num + 1
    return result

cluster = dispy.JobCluster(add_number, nodes=nodes, loglevel=dispy.logger.INFO)

jobs = []
id=1
for n in range(1,100):
    job = cluster.submit(n)
    job.id = id # Associate an ID to the job
    jobs.append(job)
    id += 1   # Next job

print( "Waiting..." )
cluster.wait()

for job in jobs:
    print(f"Job #{job.id} result is: {job.result}")

cluster.print_status()
# Out:
# Waiting...
# Job #1 result is: 2
# Job #2 result is: 3
# Job #3 result is: 4
# Job #4 result is: 5
# Job #5 result is: 6
# Job #6 result is: 7
# Job #7 result is: 8
# Job #8 result is: 9
# Job #9 result is: 10
# Job #10 result is: 11
# Job #11 result is: 12
# Job #12 result is: 13
# Job #13 result is: 14
# Job #14 result is: 15
# Job #15 result is: 16
# Job #16 result is: 17
# Job #17 result is: 18
# Job #18 result is: 19
# Job #19 result is: 20
# Job #20 result is: 21
# Job #21 result is: 22
# Job #22 result is: 23
# Job #23 result is: 24
# Job #24 result is: 25
# Job #25 result is: 26
# Job #26 result is: 27
# Job #27 result is: 28
# Job #28 result is: 29
# Job #29 result is: 30
# Job #30 result is: 31
# Job #31 result is: 32
# Job #32 result is: 33
# Job #33 result is: 34
# Job #34 result is: 35
# Job #35 result is: 36
# Job #36 result is: 37
# Job #37 result is: 38
# Job #38 result is: 39
# Job #39 result is: 40
# Job #40 result is: 41
# Job #41 result is: 42
# Job #42 result is: 43
# Job #43 result is: 44
# Job #44 result is: 45
# Job #45 result is: 46
# Job #46 result is: 47
# Job #47 result is: 48
# Job #48 result is: 49
# Job #49 result is: 50
# Job #50 result is: 51
# Job #51 result is: 52
# Job #52 result is: 53
# Job #53 result is: 54
# Job #54 result is: 55
# Job #55 result is: 56
# Job #56 result is: 57
# Job #57 result is: 58
# Job #58 result is: 59
# Job #59 result is: 60
# Job #60 result is: 61
# Job #61 result is: 62
# Job #62 result is: 63
# Job #63 result is: 64
# Job #64 result is: 65
# Job #65 result is: 66
# Job #66 result is: 67
# Job #67 result is: 68
# Job #68 result is: 69
# Job #69 result is: 70
# Job #70 result is: 71
# Job #71 result is: 72
# Job #72 result is: 73
# Job #73 result is: 74
# Job #74 result is: 75
# Job #75 result is: 76
# Job #76 result is: 77
# Job #77 result is: 78
# Job #78 result is: 79
# Job #79 result is: 80
# Job #80 result is: 81
# Job #81 result is: 82
# Job #82 result is: 83
# Job #83 result is: 84
# Job #84 result is: 85
# Job #85 result is: 86
# Job #86 result is: 87
# Job #87 result is: 88
# Job #88 result is: 89
# Job #89 result is: 90
# Job #90 result is: 91
# Job #91 result is: 92
# Job #92 result is: 93
# Job #93 result is: 94
# Job #94 result is: 95
# Job #95 result is: 96
# Job #96 result is: 97
# Job #97 result is: 98
# Job #98 result is: 99
# Job #99 result is: 100
#
#             Node |  CPUs |    Jobs |  Sec/Job | Node Time Sec |    Sent |    Rcvd
# ---------------------------------------------------------------------------------
#           Colab1 |     2 |      99 |      0.0 |           0.8 |  73.9 K |  86.8 K
#
# Total job time: 0.772 sec, wall time: 0.859 sec, speedup: 0.899

# %%
# function 'compute' is distributed and executed with arguments
# supplied with 'cluster.submit' below
def compute(n):
    import time, socket
    time.sleep(n)
    host = socket.gethostname()
    return (host, n)

#if __name__ == '__main__':
# executed on client only; variables created below, including modules imported,
# are not available in job computations
import dispy, random
# distribute 'compute' to nodes; in this case, 'compute' does not have
# any dependencies to run on nodes
cluster = dispy.JobCluster(compute)

# run 'compute' with 20 random numbers on available CPUs
jobs = []
for i in range(20):
    job = cluster.submit(random.randint(5, 20))
    jobs.append(job)
# cluster.wait() # waits until all jobs finish

for job in jobs:
    host, n = job() # waits for job to finish and returns results
    print('%s executed job %s at %s with %s' % (host, job.id, job.start_time, n))
    # other fields of 'job' that may be useful:
    # job.stdout, job.stderr, job.exception, job.ip_addr, job.end_time

cluster.print_status()  # shows which nodes executed how many jobs etc.
# Out:
# 9ab6cb613950 executed job 596 at 1773153632.3408418 with 6
# 9ab6cb613950 executed job 597 at 1773153635.3305287 with 20
# 9ab6cb613950 executed job 598 at 1773153638.3507125 with 19
# 9ab6cb613950 executed job 599 at 1773153655.3442206 with 18
# 9ab6cb613950 executed job 600 at 1773153657.3574436 with 16
# 9ab6cb613950 executed job 601 at 1773153673.3564167 with 9
# 9ab6cb613950 executed job 602 at 1773153673.364608 with 14
# 9ab6cb613950 executed job 603 at 1773153682.364441 with 5
# 9ab6cb613950 executed job 604 at 1773153687.3715522 with 10
# 9ab6cb613950 executed job 605 at 1773153687.376928 with 13
# 9ab6cb613950 executed job 606 at 1773153697.3800404 with 15
# 9ab6cb613950 executed job 607 at 1773153700.384058 with 15
# 9ab6cb613950 executed job 608 at 1773153712.3945363 with 20
# 9ab6cb613950 executed job 609 at 1773153715.3932338 with 8
# 9ab6cb613950 executed job 610 at 1773153723.4021418 with 13
# 9ab6cb613950 executed job 611 at 1773153732.4054666 with 14
# 9ab6cb613950 executed job 612 at 1773153736.4092162 with 6
# 9ab6cb613950 executed job 613 at 1773153742.4168177 with 7
# 9ab6cb613950 executed job 614 at 1773153746.4147067 with 13
# 9ab6cb613950 executed job 615 at 1773153749.424614 with 14
#
#             Node |  CPUs |    Jobs |  Sec/Job | Node Time Sec |    Sent |    Rcvd
# ---------------------------------------------------------------------------------
#           Colab1 |     2 |      20 |     12.8 |         255.1 |  84.0 K |  98.0 K
#
# Total job time: 255.084 sec, wall time: 207.029 sec, speedup: 1.232

# %% [markdown]
# # Tugas Praktikum: Pemrograman di Klaster
#
# *   Buat dua fungsi berbeda (f1, f2) yang setiap fungsinya mengembalikan nilai numerik (integer/float)
# *   Buat job untuk menjalankan 2 fungsi tersebut masing-masing 100 jobs
# *   Tunggu semua job selesai, simpan hasil ke list terpisah untuk setiap fungsi
# *   Jumlahkan semua job di setiap list dari fungsi tersebut
# *   Tampilkan hasil penjumlahan sebagai nilai akhir
# *   Buat laporan dalam PDF berisi kode dan penjelasannya
